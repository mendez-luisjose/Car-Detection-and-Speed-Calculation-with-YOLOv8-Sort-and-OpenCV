# %% [markdown]
# Importing Libraries

# %%
import cv2
import numpy as np
from datetime import datetime
from ultralytics import YOLO
from sort.sort import Sort
import os

tracker = Sort()
tracker_left = Sort()
model = YOLO("yolov8n.pt")

# %% [markdown]
# Setting Lines and Variables

# %%
BLUE_LINE = [(980, 780), (1225, 780)]
GREEN_LINE = [(980, 800), (1270, 800)]
RED_LINE = [(980, 820), (1310, 820)]

PINK_LINE = [(600, 860), (910, 860)]
YELLOW_LINE = [(580, 880), (910, 880)]
ORANGE_LINE = [(560, 900), (910, 900)]

PREV_LINE_RIGHT = [(980, 770), (1210, 770)]
PASS_LINE_RIGHT = [(995, 860), (1310, 860)]

PREV_LINE_LEFT = [(690, 770), (910, 770)]
PASS_LINE_LEFT = [(590, 860), (900, 860)]

cross_blue_line = {}
cross_green_line = {}
cross_red_line = {}

cross_pink_line = {}
cross_yellow_line = {}
cross_orange_line = {}

avg_speeds = {}

VIDEO_FPS = 30
FACTOR_KM = 3.6
LATENCY_FPS = 15

# %% [markdown]
# Euclidean Distance Function

# %%
def euclidean_distance(point1: tuple, point2: tuple) :
    x1, y1 = point1
    x2, y2 = point2
    distance = ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5
    return distance

# %% [markdown]
# Speed Calculation on the Right Side of the Road

# %%
def calculate_avg_speed_right(track_id) :
    time_bg = (cross_green_line[track_id]["time"] - cross_blue_line[track_id]["time"]).total_seconds()
    time_gr = (cross_red_line[track_id]["time"] - cross_green_line[track_id]["time"]).total_seconds()

    distance_bg = euclidean_distance(cross_green_line[track_id]["point"], cross_blue_line[track_id]["point"])
    distance_gr = euclidean_distance(cross_red_line[track_id]["point"], cross_green_line[track_id]["point"])

    speed_bg = round((distance_bg / (time_bg * VIDEO_FPS)) * (FACTOR_KM * LATENCY_FPS), 2)
    speed_gr = round((distance_gr / (time_gr * VIDEO_FPS)) * (FACTOR_KM * LATENCY_FPS), 2)

    return round((speed_bg + speed_gr) / 2, 2)

# %% [markdown]
# Speed Calculation on the Left Side of the Road

# %%
def calculate_avg_speed_left(track_id) :
    time_bg = (cross_yellow_line[track_id]["time"] - cross_orange_line[track_id]["time"]).total_seconds()
    time_gr = (cross_pink_line[track_id]["time"] - cross_yellow_line[track_id]["time"]).total_seconds()

    distance_bg = euclidean_distance(cross_yellow_line[track_id]["point"], cross_orange_line[track_id]["point"])
    distance_gr = euclidean_distance(cross_pink_line[track_id]["point"], cross_yellow_line[track_id]["point"])

    speed_bg = round((distance_bg / (time_bg * VIDEO_FPS)) * (FACTOR_KM * LATENCY_FPS), 2)
    speed_gr = round((distance_gr / (time_gr * VIDEO_FPS)) * (FACTOR_KM * LATENCY_FPS), 2)

    return round((speed_bg + speed_gr) / 2, 2)

# %%
VIDEOS_DIR = "./video"
video_path = os.path.join(VIDEOS_DIR, 'pexels_videos_2733 (1080p).mp4')
video_path_out = '{}_out.webm'.format(video_path)

cap = cv2.VideoCapture("./video/pexels_videos_2733 (1080p).mp4")

ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'vp80'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

while ret :
    height = frame.shape[0]
    width = frame.shape[1]
    cH, cW = int(height/2), int(width/2)

    mask_right = np.zeros((height, width), dtype=np.uint8)
    pts_right = np.array([[[950, 1050], [950, 580], [1030, 580], [1540, 1080]]])
    pts_right.reshape((-1,1,2))
    cv2.fillPoly(mask_right, pts_right, 255)

    mask_left = np.zeros((height, width), dtype=np.uint8)
    pts_left = np.array([[[420, 1050], [850, 580], [950, 580], [950, 1080]]])
    pts_left.reshape((-1,1,2))
    cv2.fillPoly(mask_left, pts_left, 255)

    right_zone = cv2.bitwise_and(frame, frame, mask=mask_right)
    left_zone = cv2.bitwise_and(frame, frame, mask=mask_left)

    if not ret :
        break

    results = model(right_zone, stream=True)
    results_left = model(left_zone, stream=True)

    for res in results :
        filtered_indeces = np.where((np.isin(res.boxes.cls.cpu().numpy(), [2,3,5,7])) & (res.boxes.conf.cpu().numpy() > 0.05))[0]
        boxes = res.boxes.xyxy.cpu().numpy()[filtered_indeces].astype(int)

        tracks = tracker.update(boxes)
        tracks = tracks.astype(int)

        for xmin, ymin, xmax, ymax, track_id in tracks :
            xc, yc = int((xmin+xmax) / 2), ymax

            if track_id not in cross_blue_line :
                cross_blue = (BLUE_LINE[1][0] - BLUE_LINE[0][0]) * (yc - BLUE_LINE[0][1]) - (BLUE_LINE[1][1] - BLUE_LINE[0][1]) * (xc - BLUE_LINE[0][0])
                if cross_blue >=0 :
                    cross_blue_line[track_id] = {
                        "time": datetime.now(),
                        "point": (xc, yc)
                    }
            
            elif track_id not in cross_green_line and track_id in cross_blue_line :
                cross_green = (GREEN_LINE[1][0] - GREEN_LINE[0][0]) * (yc - GREEN_LINE[0][1]) - (GREEN_LINE[1][1] - GREEN_LINE[0][1]) * (xc - GREEN_LINE[0][0])
                if cross_green >=0 :
                    cross_green_line[track_id] = {
                        "time": datetime.now(),
                        "point": (xc, yc)
                    }

            elif track_id not in cross_red_line and track_id in cross_green_line :
                cross_red = (RED_LINE[1][0] - RED_LINE[0][0]) * (yc - RED_LINE[0][1]) - (RED_LINE[1][1] - RED_LINE[0][1]) * (xc - RED_LINE[0][0])
                if cross_red >=0 :
                    cross_red_line[track_id] = {
                        "time": datetime.now(),
                        "point": (xc, yc)
                    }

                    avg_speed = calculate_avg_speed_right(track_id)
                    avg_speeds[track_id] = f"{avg_speed} km/h"
  
            cross_line_right = (PASS_LINE_RIGHT[1][0] - PASS_LINE_RIGHT[0][0]) * (yc - PASS_LINE_RIGHT[0][1]) - (PASS_LINE_RIGHT[1][1] - PASS_LINE_RIGHT[0][1]) * (xc - PASS_LINE_RIGHT[0][0])

            if track_id in avg_speeds and track_id in cross_blue_line and track_id in cross_green_line and track_id in cross_red_line and cross_line_right <= 0:
               cv2.putText(img=frame, text=avg_speeds[track_id], org=(xmin, ymin-10), fontFace=cv2.FONT_HERSHEY_PLAIN, fontScale=1, color=(0,255,0), thickness=2)

            cv2.rectangle(img=frame, pt1=(xmin, ymin), pt2=(xmax, ymax), color=(255, 255, 0), thickness=2)

    for res in results_left :
        filtered_indeces = np.where((np.isin(res.boxes.cls.cpu().numpy(), [2,3,5,7])) & (res.boxes.conf.cpu().numpy() > 0.05))[0]
        boxes = res.boxes.xyxy.cpu().numpy()[filtered_indeces].astype(int)

        tracks_left = tracker_left.update(boxes)
        tracks_left = tracks_left.astype(int)

        for xmin, ymin, xmax, ymax, track_id in tracks_left :
            xc, yc = int((xmin+xmax) / 2), ymax

            if track_id not in cross_orange_line :
                cross_orange = (ORANGE_LINE[1][0] - ORANGE_LINE[0][0]) * (yc - ORANGE_LINE[0][1]) - (ORANGE_LINE[1][1] - ORANGE_LINE[0][1]) * (xc - ORANGE_LINE[0][0])
                if cross_orange <=0 :
                    cross_orange_line[track_id] = {
                        "time": datetime.now(),
                        "point": (xc, yc)
                    }
            elif track_id not in cross_yellow_line and track_id in cross_orange_line :
                cross_yellow = (YELLOW_LINE[1][0] - YELLOW_LINE[0][0]) * (yc - YELLOW_LINE[0][1]) - (YELLOW_LINE[1][1] - YELLOW_LINE[0][1]) * (xc - YELLOW_LINE[0][0])
                if cross_yellow <=0 :
                    cross_yellow_line[track_id] = {
                        "time": datetime.now(),
                        "point": (xc, yc)
                    }

            elif track_id not in cross_pink_line and track_id in cross_yellow_line :
                cross_pink = (PINK_LINE[1][0] - PINK_LINE[0][0]) * (yc - PINK_LINE[0][1]) - (PINK_LINE[1][1] - PINK_LINE[0][1]) * (xc - PINK_LINE[0][0])
                if cross_pink <=0 :
                    cross_pink_line[track_id] = {
                        "time": datetime.now(),
                        "point": (xc, yc)
                    }

                    avg_speed = calculate_avg_speed_left(track_id)
                    avg_speeds[track_id] = f"{avg_speed} km/h" 

            cross_line_left = (PREV_LINE_LEFT[1][0] - PREV_LINE_LEFT[0][0]) * (yc - PREV_LINE_LEFT[0][1]) - (PREV_LINE_LEFT[1][1] - PREV_LINE_LEFT[0][1]) * (xc - PREV_LINE_LEFT[0][0])
            
            if track_id in avg_speeds and track_id in cross_orange_line and track_id in cross_yellow_line and track_id in cross_pink_line and cross_line_left >= 0:
               cv2.putText(img=frame, text=avg_speeds[track_id], org=(xmin, ymin-10), fontFace=cv2.FONT_HERSHEY_PLAIN, fontScale=1, color=(0,255,0), thickness=2) 

            cv2.rectangle(img=frame, pt1=(xmin, ymin), pt2=(xmax, ymax), color=(255, 255, 0), thickness=2)
    
    cv2.line(frame, PASS_LINE_RIGHT[0], PASS_LINE_RIGHT[1], (0, 0, 255), 3)
    cv2.line(frame, PREV_LINE_RIGHT[0], PREV_LINE_RIGHT[1], (252, 111, 3), 3)

    cv2.line(frame, PASS_LINE_LEFT[0], PASS_LINE_LEFT[1], (255, 0, 255), 3)
    cv2.line(frame, PREV_LINE_LEFT[0], PREV_LINE_LEFT[1], (0, 255, 255), 3)

    #cv2.imshow("Frame", frame)
    out.write(frame)
    
    ret, frame = cap.read()

    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 cars, 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.4ms
# Speed: 2.4ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 93.4ms
# Speed: 1.0ms preprocess, 93.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.2ms
# Speed: 2.3ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 91.7ms
# Speed: 2.3ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 105.6ms
# Speed: 3.0ms preprocess, 105.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 97.8ms
# Speed: 4.0ms preprocess, 97.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 88.3ms
# Speed: 3.5ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.3ms
# Speed: 2.4ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 77.3ms
# Speed: 3.0ms preprocess, 77.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 83.4ms
# Speed: 3.5ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 84.5ms
# Speed: 3.2ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 77.7ms
# Speed: 2.8ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.6ms
# Speed: 2.4ms preprocess, 82.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 78.6ms
# Speed: 2.9ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 76.7ms
# Speed: 2.7ms preprocess, 76.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.2ms
# Speed: 3.7ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 116.9ms
# Speed: 3.0ms preprocess, 116.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 79.9ms
# Speed: 2.6ms preprocess, 79.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 99.3ms
# Speed: 3.5ms preprocess, 99.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 90.4ms
# Speed: 3.0ms preprocess, 90.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 116.6ms
# Speed: 3.4ms preprocess, 116.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 126.5ms
# Speed: 5.3ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 129.6ms
# Speed: 3.6ms preprocess, 129.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 84.1ms
# Speed: 3.7ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 78.8ms
# Speed: 4.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.2ms
# Speed: 2.3ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.1ms
# Speed: 2.5ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 71.5ms
# Speed: 2.6ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 94.2ms
# Speed: 2.5ms preprocess, 94.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 90.1ms
# Speed: 2.9ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 97.5ms
# Speed: 3.5ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.0ms
# Speed: 2.1ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 67.4ms
# Speed: 3.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.7ms
# Speed: 3.0ms preprocess, 68.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 67.3ms
# Speed: 2.5ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.4ms
# Speed: 3.1ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 73.4ms
# Speed: 1.9ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 77.4ms
# Speed: 2.5ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 80.8ms
# Speed: 2.6ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 90.6ms
# Speed: 6.8ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 87.5ms
# Speed: 3.5ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 70.6ms
# Speed: 1.9ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 70.1ms
# Speed: 3.0ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.6ms
# Speed: 2.6ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.7ms
# Speed: 3.5ms preprocess, 82.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.7ms
# Speed: 2.0ms preprocess, 82.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 74.1ms
# Speed: 2.5ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.9ms
# Speed: 1.6ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.2ms
# Speed: 2.5ms preprocess, 69.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 80.4ms
# Speed: 3.0ms preprocess, 80.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.9ms
# Speed: 2.0ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 85.7ms
# Speed: 3.1ms preprocess, 85.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.4ms
# Speed: 2.9ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.2ms
# Speed: 2.0ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.6ms
# Speed: 2.0ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 78.7ms
# Speed: 3.4ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.3ms
# Speed: 3.0ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 77.3ms
# Speed: 3.3ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 76.3ms
# Speed: 2.5ms preprocess, 76.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.7ms
# Speed: 2.5ms preprocess, 79.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.6ms
# Speed: 2.2ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 80.9ms
# Speed: 2.0ms preprocess, 80.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 86.5ms
# Speed: 2.6ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 89.6ms
# Speed: 2.5ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.7ms
# Speed: 2.6ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.7ms
# Speed: 2.6ms preprocess, 75.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 77.9ms
# Speed: 3.3ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.3ms
# Speed: 3.0ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 73.3ms
# Speed: 2.0ms preprocess, 73.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 110.2ms
# Speed: 3.0ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 67.6ms
# Speed: 3.0ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 62.1ms
# Speed: 3.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 73.9ms
# Speed: 2.0ms preprocess, 73.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 68.0ms
# Speed: 2.6ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 77.2ms
# Speed: 3.3ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.9ms
# Speed: 3.0ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 89.4ms
# Speed: 2.9ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.5ms
# Speed: 3.0ms preprocess, 82.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 72.8ms
# Speed: 3.5ms preprocess, 72.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 90.7ms
# Speed: 2.5ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 69.9ms
# Speed: 2.6ms preprocess, 69.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 88.7ms
# Speed: 2.5ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.3ms
# Speed: 3.3ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 84.2ms
# Speed: 3.0ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.5ms
# Speed: 3.5ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 98.9ms
# Speed: 2.7ms preprocess, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 98.0ms
# Speed: 4.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.7ms
# Speed: 3.7ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 67.9ms
# Speed: 2.0ms preprocess, 67.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 124.6ms
# Speed: 2.6ms preprocess, 124.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 87.0ms
# Speed: 3.6ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 93.5ms
# Speed: 3.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.6ms
# Speed: 2.6ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 67.0ms
# Speed: 3.1ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 67.2ms
# Speed: 2.4ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.5ms
# Speed: 3.5ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 96.3ms
# Speed: 3.1ms preprocess, 96.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 96.2ms
# Speed: 4.9ms preprocess, 96.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 111.0ms
# Speed: 3.0ms preprocess, 111.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.8ms
# Speed: 3.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.9ms
# Speed: 2.7ms preprocess, 71.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 73.7ms
# Speed: 3.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.3ms
# Speed: 3.9ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 87.5ms
# Speed: 3.6ms preprocess, 87.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 92.5ms
# Speed: 1.6ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 76.5ms
# Speed: 3.4ms preprocess, 76.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 79.9ms
# Speed: 2.1ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 78.1ms
# Speed: 3.6ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.4ms
# Speed: 2.0ms preprocess, 72.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 86.2ms
# Speed: 2.1ms preprocess, 86.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 98.8ms
# Speed: 3.7ms preprocess, 98.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 77.1ms
# Speed: 3.8ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 75.3ms
# Speed: 2.3ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.7ms
# Speed: 3.0ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 92.0ms
# Speed: 3.0ms preprocess, 92.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.0ms
# Speed: 2.5ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 83.0ms
# Speed: 2.7ms preprocess, 83.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.0ms
# Speed: 2.3ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.4ms
# Speed: 2.5ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.2ms
# Speed: 3.5ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.9ms
# Speed: 4.0ms preprocess, 94.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 94.2ms
# Speed: 3.8ms preprocess, 94.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 3.5ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 94.8ms
# Speed: 4.8ms preprocess, 94.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.8ms
# Speed: 2.5ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 106.9ms
# Speed: 4.0ms preprocess, 106.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.7ms
# Speed: 3.1ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 75.4ms
# Speed: 2.2ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.4ms
# Speed: 2.1ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 72.2ms
# Speed: 2.4ms preprocess, 72.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 80.7ms
# Speed: 2.5ms preprocess, 80.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.2ms
# Speed: 1.9ms preprocess, 69.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 70.1ms
# Speed: 2.5ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.5ms
# Speed: 1.7ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 67.5ms
# Speed: 2.1ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.7ms
# Speed: 3.0ms preprocess, 82.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 77.2ms
# Speed: 3.0ms preprocess, 77.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.7ms
# Speed: 3.2ms preprocess, 92.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 77.1ms
# Speed: 2.2ms preprocess, 77.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 79.7ms
# Speed: 2.2ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 73.1ms
# Speed: 2.9ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.6ms
# Speed: 2.0ms preprocess, 83.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 115.3ms
# Speed: 4.2ms preprocess, 115.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.5ms
# Speed: 2.6ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 72.9ms
# Speed: 2.4ms preprocess, 72.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.6ms
# Speed: 2.5ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 93.0ms
# Speed: 2.5ms preprocess, 93.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.1ms
# Speed: 2.6ms preprocess, 100.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 3.0ms preprocess, 69.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 78.3ms
# Speed: 2.6ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 74.7ms
# Speed: 2.1ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.4ms
# Speed: 4.8ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 80.3ms
# Speed: 3.1ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.1ms
# Speed: 2.0ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 77.9ms
# Speed: 2.5ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 2.0ms preprocess, 85.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 74.2ms
# Speed: 3.4ms preprocess, 74.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.7ms
# Speed: 2.6ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 77.1ms
# Speed: 3.0ms preprocess, 77.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.1ms
# Speed: 2.5ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 77.7ms
# Speed: 2.5ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.1ms
# Speed: 3.2ms preprocess, 79.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.7ms
# Speed: 3.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.1ms
# Speed: 2.4ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.2ms
# Speed: 4.0ms preprocess, 72.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.9ms
# Speed: 3.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 66.7ms
# Speed: 3.0ms preprocess, 66.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 70.7ms
# Speed: 3.5ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 66.1ms
# Speed: 2.6ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.8ms
# Speed: 4.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 85.2ms
# Speed: 3.9ms preprocess, 85.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 2.2ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.4ms
# Speed: 1.0ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.9ms
# Speed: 3.3ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 89.2ms
# Speed: 3.0ms preprocess, 89.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.9ms
# Speed: 3.3ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.2ms
# Speed: 3.5ms preprocess, 100.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 3.2ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.3ms
# Speed: 2.5ms preprocess, 104.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 101.3ms
# Speed: 4.5ms preprocess, 101.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.2ms
# Speed: 3.2ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 86.7ms
# Speed: 3.5ms preprocess, 86.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.0ms
# Speed: 2.3ms preprocess, 78.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.5ms
# Speed: 2.0ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.7ms
# Speed: 2.8ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.6ms
# Speed: 3.0ms preprocess, 83.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 97.7ms
# Speed: 2.1ms preprocess, 97.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.0ms
# Speed: 8.6ms preprocess, 112.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.5ms
# Speed: 2.5ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.3ms
# Speed: 3.0ms preprocess, 99.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 3.0ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 2.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.9ms
# Speed: 1.2ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 91.4ms
# Speed: 4.6ms preprocess, 91.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.6ms
# Speed: 2.3ms preprocess, 75.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.8ms
# Speed: 2.9ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.6ms
# Speed: 2.5ms preprocess, 73.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.3ms
# Speed: 2.2ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 69.9ms
# Speed: 3.0ms preprocess, 69.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 77.7ms
# Speed: 2.6ms preprocess, 77.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.1ms
# Speed: 3.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.5ms
# Speed: 2.1ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 2.0ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 86.2ms
# Speed: 2.0ms preprocess, 86.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.6ms
# Speed: 3.2ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.8ms
# Speed: 4.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.4ms
# Speed: 3.6ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 78.3ms
# Speed: 2.5ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 70.7ms
# Speed: 3.3ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 85.9ms
# Speed: 3.0ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.1ms
# Speed: 2.5ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 80.7ms
# Speed: 3.4ms preprocess, 80.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.6ms
# Speed: 2.3ms preprocess, 88.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.3ms
# Speed: 3.3ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 71.4ms
# Speed: 2.6ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 71.6ms
# Speed: 2.0ms preprocess, 71.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 65.4ms
# Speed: 3.1ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 66.6ms
# Speed: 2.9ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.3ms
# Speed: 3.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 72.1ms
# Speed: 2.6ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.7ms
# Speed: 2.3ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 93.2ms
# Speed: 3.1ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.5ms
# Speed: 3.1ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.2ms
# Speed: 2.9ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 67.9ms
# Speed: 3.2ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 71.7ms
# Speed: 2.6ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 73.4ms
# Speed: 3.0ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 68.7ms
# Speed: 1.8ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 69.3ms
# Speed: 2.7ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 70.7ms
# Speed: 2.6ms preprocess, 70.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 2.0ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.8ms
# Speed: 3.1ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.5ms
# Speed: 3.9ms preprocess, 72.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.2ms
# Speed: 3.0ms preprocess, 71.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.3ms
# Speed: 3.0ms preprocess, 76.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 92.9ms
# Speed: 2.9ms preprocess, 92.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.1ms
# Speed: 2.5ms preprocess, 66.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.4ms
# Speed: 2.6ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.3ms
# Speed: 3.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 80.9ms
# Speed: 2.2ms preprocess, 80.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.7ms
# Speed: 6.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 82.1ms
# Speed: 3.0ms preprocess, 82.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.3ms
# Speed: 3.4ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 87.1ms
# Speed: 2.5ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.3ms
# Speed: 2.3ms preprocess, 82.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 69.8ms
# Speed: 4.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 72.3ms
# Speed: 2.4ms preprocess, 72.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 76.9ms
# Speed: 2.2ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.8ms
# Speed: 3.5ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.3ms
# Speed: 3.5ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 65.9ms
# Speed: 2.5ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.6ms
# Speed: 2.5ms preprocess, 81.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 69.2ms
# Speed: 2.4ms preprocess, 69.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 77.9ms
# Speed: 3.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.1ms
# Speed: 3.0ms preprocess, 66.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 83.8ms
# Speed: 3.5ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 91.5ms
# Speed: 3.0ms preprocess, 91.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 69.2ms
# Speed: 2.0ms preprocess, 69.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 truck, 69.0ms
# Speed: 2.9ms preprocess, 69.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 77.5ms
# Speed: 2.2ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 78.3ms
# Speed: 2.0ms preprocess, 78.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 70.8ms
# Speed: 2.4ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 70.2ms
# Speed: 3.0ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.2ms
# Speed: 2.5ms preprocess, 82.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 84.9ms
# Speed: 2.0ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.0ms
# Speed: 3.5ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 78.2ms
# Speed: 1.6ms preprocess, 78.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.7ms
# Speed: 2.5ms preprocess, 78.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 78.1ms
# Speed: 3.0ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 80.7ms
# Speed: 2.0ms preprocess, 80.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 3.5ms preprocess, 69.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 77.9ms
# Speed: 3.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 82.5ms
# Speed: 2.0ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 3.5ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 82.0ms
# Speed: 2.6ms preprocess, 82.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 85.1ms
# Speed: 2.5ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 81.3ms
# Speed: 2.1ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 76.0ms
# Speed: 3.6ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 74.4ms
# Speed: 2.5ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 75.3ms
# Speed: 2.5ms preprocess, 75.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.7ms
# Speed: 3.6ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 80.6ms
# Speed: 2.5ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 72.6ms
# Speed: 2.0ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 truck, 85.0ms
# Speed: 1.8ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.3ms
# Speed: 2.4ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 truck, 71.7ms
# Speed: 2.0ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 2.5ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 truck, 88.1ms
# Speed: 2.5ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.7ms
# Speed: 2.0ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 truck, 86.3ms
# Speed: 2.3ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 74.4ms
# Speed: 3.3ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 truck, 81.8ms
# Speed: 2.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 truck, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 70.1ms
# Speed: 2.0ms preprocess, 70.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 truck, 116.4ms
# Speed: 2.2ms preprocess, 116.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.4ms
# Speed: 4.5ms preprocess, 103.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 truck, 107.3ms
# Speed: 3.5ms preprocess, 107.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.5ms
# Speed: 3.6ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 90.4ms
# Speed: 2.0ms preprocess, 90.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.5ms
# Speed: 3.0ms preprocess, 102.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 85.3ms
# Speed: 3.5ms preprocess, 85.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.5ms
# Speed: 2.5ms preprocess, 89.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 99.2ms
# Speed: 2.6ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 2.5ms preprocess, 98.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 112.6ms
# Speed: 2.6ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.7ms
# Speed: 2.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 106.5ms
# Speed: 3.0ms preprocess, 106.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.8ms
# Speed: 3.8ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 94.3ms
# Speed: 3.0ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 113.3ms
# Speed: 3.3ms preprocess, 113.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.1ms
# Speed: 3.9ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 102.8ms
# Speed: 3.0ms preprocess, 102.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.0ms
# Speed: 4.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 93.7ms
# Speed: 3.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 2.0ms preprocess, 98.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 87.3ms
# Speed: 2.5ms preprocess, 87.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 3.5ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 94.7ms
# ...
#
# 0: 384x640 3 cars, 79.3ms
# Speed: 2.1ms preprocess, 79.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.8ms
# Speed: 3.3ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 90.4ms
# Speed: 2.3ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 138.1ms
# Speed: 4.1ms preprocess, 138.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 138.4ms
# Speed: 3.2ms preprocess, 138.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 127.7ms
# Speed: 4.6ms preprocess, 127.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 120.2ms
# Speed: 3.2ms preprocess, 120.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 90.9ms
# Speed: 3.3ms preprocess, 90.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 78.1ms
# Speed: 3.9ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 77.4ms
# Speed: 2.1ms preprocess, 77.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 76.9ms
# Speed: 3.0ms preprocess, 76.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 91.3ms
# Speed: 2.4ms preprocess, 91.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 77.0ms
# Speed: 2.9ms preprocess, 77.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 85.1ms
# Speed: 3.0ms preprocess, 85.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 89.0ms
# Speed: 4.3ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 89.0ms
# Speed: 2.6ms preprocess, 89.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 81.2ms
# Speed: 3.2ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 101.9ms
# Speed: 3.0ms preprocess, 101.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 92.9ms
# Speed: 3.0ms preprocess, 92.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 80.6ms
# Speed: 2.5ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 81.7ms
# Speed: 3.0ms preprocess, 81.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 74.5ms
# Speed: 3.5ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 74.2ms
# Speed: 2.9ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 87.5ms
# Speed: 2.6ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 74.9ms
# Speed: 3.0ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 75.3ms
# Speed: 3.5ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 80.3ms
# Speed: 2.0ms preprocess, 80.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 75.3ms
# Speed: 2.5ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 78.9ms
# Speed: 2.0ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 76.0ms
# Speed: 2.3ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 77.2ms
# Speed: 3.6ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.6ms
# Speed: 2.5ms preprocess, 82.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 85.0ms
# Speed: 2.5ms preprocess, 85.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 113.0ms
# Speed: 4.7ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 93.0ms
# Speed: 2.9ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.7ms
# Speed: 3.0ms preprocess, 81.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 78.7ms
# Speed: 2.5ms preprocess, 78.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 118.8ms
# Speed: 4.0ms preprocess, 118.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 111.1ms
# Speed: 2.1ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.1ms
# Speed: 3.0ms preprocess, 82.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 77.9ms
# Speed: 3.2ms preprocess, 77.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 142.6ms
# Speed: 4.3ms preprocess, 142.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 87.5ms
# Speed: 4.6ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 79.9ms
# Speed: 4.0ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 76.0ms
# Speed: 3.2ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 82.3ms
# Speed: 2.3ms preprocess, 82.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 99.8ms
# Speed: 2.1ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.4ms
# Speed: 2.5ms preprocess, 72.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 78.6ms
# Speed: 3.2ms preprocess, 78.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 78.7ms
# Speed: 2.1ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 71.3ms
# Speed: 2.7ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 75.9ms
# Speed: 2.3ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 75.7ms
# Speed: 2.8ms preprocess, 75.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 81.9ms
# Speed: 3.0ms preprocess, 81.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 83.7ms
# Speed: 3.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 80.7ms
# Speed: 2.0ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 82.9ms
# Speed: 2.5ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.7ms
# Speed: 2.1ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 94.2ms
# Speed: 3.5ms preprocess, 94.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 76.1ms
# Speed: 3.1ms preprocess, 76.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.6ms
# Speed: 2.5ms preprocess, 79.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 68.9ms
# Speed: 2.2ms preprocess, 68.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 82.9ms
# Speed: 3.5ms preprocess, 82.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 114.0ms
# Speed: 3.3ms preprocess, 114.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 105.2ms
# Speed: 3.3ms preprocess, 105.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 94.2ms
# Speed: 3.0ms preprocess, 94.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 119.8ms
# Speed: 5.0ms preprocess, 119.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 143.3ms
# Speed: 2.6ms preprocess, 143.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 109.4ms
# Speed: 3.0ms preprocess, 109.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 77.7ms
# Speed: 2.5ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 88.1ms
# Speed: 3.4ms preprocess, 88.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 102.3ms
# Speed: 5.0ms preprocess, 102.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 83.6ms
# Speed: 3.2ms preprocess, 83.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.8ms
# Speed: 3.0ms preprocess, 86.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 72.3ms
# Speed: 2.0ms preprocess, 72.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 75.8ms
# Speed: 3.0ms preprocess, 75.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 89.1ms
# Speed: 3.2ms preprocess, 89.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.1ms
# Speed: 2.0ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 92.0ms
# Speed: 3.2ms preprocess, 92.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 83.8ms
# Speed: 2.0ms preprocess, 83.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 89.9ms
# Speed: 3.5ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 90.7ms
# Speed: 3.5ms preprocess, 90.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 84.2ms
# Speed: 3.0ms preprocess, 84.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 100.2ms
# Speed: 2.8ms preprocess, 100.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 96.3ms
# Speed: 3.8ms preprocess, 96.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 121.7ms
# Speed: 5.5ms preprocess, 121.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 128.3ms
# Speed: 4.0ms preprocess, 128.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 78.8ms
# Speed: 3.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 91.1ms
# Speed: 2.1ms preprocess, 91.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 80.9ms
# Speed: 3.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 76.9ms
# Speed: 3.0ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 77.6ms
# Speed: 3.0ms preprocess, 77.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 125.1ms
# Speed: 5.6ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 92.1ms
# Speed: 3.5ms preprocess, 92.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 103.9ms
# Speed: 4.5ms preprocess, 103.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.4ms
# Speed: 3.0ms preprocess, 104.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 135.9ms
# Speed: 4.4ms preprocess, 135.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 91.4ms
# Speed: 2.7ms preprocess, 91.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 124.4ms
# Speed: 3.6ms preprocess, 124.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 113.6ms
# Speed: 3.0ms preprocess, 113.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 150.6ms
# Speed: 5.9ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 134.2ms
# Speed: 3.5ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 133.4ms
# Speed: 3.8ms preprocess, 133.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 92.9ms
# Speed: 3.0ms preprocess, 92.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.7ms
# Speed: 2.0ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 84.7ms
# Speed: 3.5ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 93.1ms
# Speed: 3.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 78.4ms
# Speed: 2.5ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 113.0ms
# Speed: 3.5ms preprocess, 113.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 128.7ms
# Speed: 3.6ms preprocess, 128.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 84.9ms
# Speed: 3.0ms preprocess, 84.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
